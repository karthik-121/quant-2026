# %%
first_10_squares = [x**2 for x in range(1,11)]
even_numbers = [x for x in range(0,101) if x%2 == 0]
greater_than_threshold = [x for x in range(0,11) if x > 5]
print(greater_than_threshold)
# Out:
# [6, 7, 8, 9, 10]

# %%
import sys
from pathlib import Path
# Get the path of the current notebook directory (notebooks)
notebook_dir = Path.cwd()

# Define the path to the 'src' directory (sibling to 'notebooks')
src_dir = notebook_dir.parent.parent / 'src'

# Add the source directory to sys.path if it's not already present
if str(src_dir) not in sys.path:
    sys.path.append(str(src_dir))
    print(f"Added {src_dir} to sys.path")

print(sys.path)
# Out:
# /Users/karthikiyer/Desktop/quant-2026/notebooks/practice
# ['/Users/karthikiyer/Desktop/quant-2026/notebooks/practice', '/Users/karthikiyer/.vscode/extensions/ms-toolsai.jupyter-2021.2.576440691/pythonFiles/vscode_datascience_helpers/../.does-not-exist', '/Users/karthikiyer/.vscode/extensions/ms-toolsai.jupyter-2021.2.576440691/pythonFiles', '/Users/karthikiyer/.vscode/extensions/ms-toolsai.jupyter-2021.2.576440691/pythonFiles/lib/python', '/opt/anaconda3/lib/python312.zip', '/opt/anaconda3/lib/python3.12', '/opt/anaconda3/lib/python3.12/lib-dynload', '', '/opt/anaconda3/lib/python3.12/site-packages', '/opt/anaconda3/lib/python3.12/site-packages/aeosa', '/opt/anaconda3/lib/python3.12/site-packages/setuptools/_vendor', '/Users/karthikiyer/Desktop/quant-2026/src']

# %%
from importlib import reload
from quant_math import derivatives

def f(x):
    return x**2

reload(derivatives)
derivatives.numerical_derivative(f,3)
derivatives.second_derivative(f,3)
# Out:
# 1.9999824019123478
